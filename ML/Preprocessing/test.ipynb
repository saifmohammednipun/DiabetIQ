# %% [markdown]
# # Data Loading

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sklearn as scikit_learn

# %%
csv_path = "/Users/saifmohammed/Desktop/CSE299-Junior-Design-Project/ML/Test/Copy Dataset/Diabetes_Final_Data_V21.csv"
df = pd.read_csv(csv_path)
df
# Out:
#       age  gender  pulse_rate  systolic_bp  diastolic_bp  glucose  height  \
# 0      42  Female          66          110            73     5.88    1.65
# 1      35  Female          60          125            68     5.71    1.47
# 2      62  Female          57          127            74     6.85    1.52
# 3      73    Male          55          193           112     6.28    1.63
# 4      68  Female          71          150            81     5.71    1.42
# ...   ...     ...         ...          ...           ...      ...     ...
# 5432   74    Male          83          164            89     6.47    1.60
# 5433   75    Male          67          141           104     8.31    1.65
# 5434   40  Female          67          134           114     7.61    1.50
# 5435   36  Female          62          139            80     4.90    1.52
# 5436   26  Female          80          134            93     5.15    1.47
#
#       weight    bmi  family_diabetes  hypertensive  family_hypertension  \
# ...

# %%
df.head()
# Out:
#    age  gender  pulse_rate  systolic_bp  diastolic_bp  glucose  height  \
# 0   42  Female          66          110            73     5.88    1.65
# 1   35  Female          60          125            68     5.71    1.47
# 2   62  Female          57          127            74     6.85    1.52
# 3   73    Male          55          193           112     6.28    1.63
# 4   68  Female          71          150            81     5.71    1.42
#
#    weight    bmi  family_diabetes  hypertensive  family_hypertension  \
# 0    70.2  25.75                0             0                    0
# 1    42.5  19.58                0             0                    0
# 2    47.0  20.24                0             0                    0
# 3    57.4  21.72                0             0                    0
# 4    36.0  17.79                0             0                    0
#
#    cardiovascular_disease  stroke diabetic
# 0                       0       0       No
# ...

# %%
df.tail()
# Out:
#       age  gender  pulse_rate  systolic_bp  diastolic_bp  glucose  height  \
# 5432   74    Male          83          164            89     6.47    1.60
# 5433   75    Male          67          141           104     8.31    1.65
# 5434   40  Female          67          134           114     7.61    1.50
# 5435   36  Female          62          139            80     4.90    1.52
# 5436   26  Female          80          134            93     5.15    1.47
#
#       weight    bmi  family_diabetes  hypertensive  family_hypertension  \
# 5432    64.0  24.99                0             1                    0
# 5433    62.0  22.75                0             0                    0
# 5434    69.0  30.72                0             1                    0
# 5435    41.5  17.87                0             0                    0
# 5436    67.1  30.92                0             0                    0
#
#       cardiovascular_disease  stroke diabetic
# ...

# %%
df.shape
# Out:
# (5437, 15)

# %%
df.columns
# Out:
# Index(['age', 'gender', 'pulse_rate', 'systolic_bp', 'diastolic_bp', 'glucose',
#        'height', 'weight', 'bmi', 'family_diabetes', 'hypertensive',
#        'family_hypertension', 'cardiovascular_disease', 'stroke', 'diabetic'],
#       dtype='object')

# %%
df.loc[df['gender']== 'Female']
# Out:
#       age  gender  pulse_rate  systolic_bp  diastolic_bp  glucose  height  \
# 0      42  Female          66          110            73     5.88    1.65
# 1      35  Female          60          125            68     5.71    1.47
# 2      62  Female          57          127            74     6.85    1.52
# 4      68  Female          71          150            81     5.71    1.42
# 6      35  Female          66          123            72     5.40    1.42
# ...   ...     ...         ...          ...           ...      ...     ...
# 5429   65  Female          76          158            96     7.03    1.45
# 5430   58  Female          67          141            76     6.25    1.57
# 5434   40  Female          67          134           114     7.61    1.50
# 5435   36  Female          62          139            80     4.90    1.52
# 5436   26  Female          80          134            93     5.15    1.47
#
#       weight    bmi  family_diabetes  hypertensive  family_hypertension  \
# ...

# %%
df.loc[df['gender']== 'Male']
# Out:
#       age gender  pulse_rate  systolic_bp  diastolic_bp  glucose  height  \
# 3      73   Male          55          193           112     6.28    1.63
# 5      40   Male          48          131            73     7.22    1.63
# 8      50   Male          80          135            87    17.04    1.68
# 9      70   Male          64          129            75     8.04    1.65
# 16     54   Male          99          152            68    15.00    1.60
# ...   ...    ...         ...          ...           ...      ...     ...
# 5420   34   Male          72          112            76     5.74    1.65
# 5426   48   Male          67          150           101     6.98    1.68
# 5431   70   Male          68          146            77     9.42    1.60
# 5432   74   Male          83          164            89     6.47    1.60
# 5433   75   Male          67          141           104     8.31    1.65
#
#       weight    bmi  family_diabetes  hypertensive  family_hypertension  \
# ...

# %%
df.loc[df['diabetic']== 'Yes']
# Out:
#       age  gender  pulse_rate  systolic_bp  diastolic_bp  glucose  height  \
# 8      50    Male          80          135            87    17.04    1.68
# 15     35  Female          89          147            90    13.60    1.52
# 16     54    Male          99          152            68    15.00    1.60
# 17     65  Female          89          129            86    24.50    1.52
# 24     60  Female          64          149            88    15.66    1.45
# ...   ...     ...         ...          ...           ...      ...     ...
# 5325   30    Male          88          120            80    12.00    1.60
# 5402   55    Male          67          138            80     8.12    1.73
# 5403   45    Male          67          148           102     6.79    1.65
# 5412   50    Male          85          127            79     7.78    1.63
# 5433   75    Male          67          141           104     8.31    1.65
#
#       weight    bmi  family_diabetes  hypertensive  family_hypertension  \
# ...

# %%
df.loc[df['diabetic']== 'No']
# Out:
#       age  gender  pulse_rate  systolic_bp  diastolic_bp  glucose  height  \
# 0      42  Female          66          110            73     5.88    1.65
# 1      35  Female          60          125            68     5.71    1.47
# 2      62  Female          57          127            74     6.85    1.52
# 3      73    Male          55          193           112     6.28    1.63
# 4      68  Female          71          150            81     5.71    1.42
# ...   ...     ...         ...          ...           ...      ...     ...
# 5431   70    Male          68          146            77     9.42    1.60
# 5432   74    Male          83          164            89     6.47    1.60
# 5434   40  Female          67          134           114     7.61    1.50
# 5435   36  Female          62          139            80     4.90    1.52
# 5436   26  Female          80          134            93     5.15    1.47
#
#       weight    bmi  family_diabetes  hypertensive  family_hypertension  \
# ...

# %%
df.loc[(df['diabetic']== 'Yes')& (df['gender']== 'Female')]
# Out:
#       age  gender  pulse_rate  systolic_bp  diastolic_bp  glucose  height  \
# 15     35  Female          89          147            90    13.60    1.52
# 17     65  Female          89          129            86    24.50    1.52
# 24     60  Female          64          149            88    15.66    1.45
# 35     52  Female          69          212           110     6.21    1.32
# 78     38  Female          99          123            52    12.00    1.57
# ...   ...     ...         ...          ...           ...      ...     ...
# 5206   51  Female          71          163            94     5.27    1.50
# 5234   60  Female          75          119            78    15.67    1.55
# 5283   60  Female          63          181           115     8.31    1.50
# 5292   52  Female          57          175           100     9.28    1.52
# 5313   40  Female          74          190           103    13.50    1.52
#
#       weight    bmi  family_diabetes  hypertensive  family_hypertension  \
# ...

# %%
df.loc[(df['diabetic']== 'Yes')& (df['gender']== 'Male')]
# Out:
#       age gender  pulse_rate  systolic_bp  diastolic_bp  glucose  height  \
# 8      50   Male          80          135            87    17.04    1.68
# 16     54   Male          99          152            68    15.00    1.60
# 32     75   Male          59          171            86     6.18    1.68
# 33     57   Male          57          184           106     7.00    1.57
# 47     68   Male          67          135            83     5.25    1.55
# ...   ...    ...         ...          ...           ...      ...     ...
# 5325   30   Male          88          120            80    12.00    1.60
# 5402   55   Male          67          138            80     8.12    1.73
# 5403   45   Male          67          148           102     6.79    1.65
# 5412   50   Male          85          127            79     7.78    1.63
# 5433   75   Male          67          141           104     8.31    1.65
#
#       weight    bmi  family_diabetes  hypertensive  family_hypertension  \
# ...

# %%
df.describe()
# Out:
#                age   pulse_rate  systolic_bp  diastolic_bp      glucose  \
# count  5437.000000  5437.000000  5437.000000   5437.000000  5437.000000
# mean     45.533750    76.768990   133.859849     82.064742     7.540682
# std      14.321155    12.290076    22.293015     12.489593     2.923080
# min       8.000000     5.000000    62.000000     45.000000     0.000000
# 25%      35.000000    69.000000   119.000000     73.000000     6.000000
# 50%      45.000000    76.000000   130.000000     81.000000     6.920000
# 75%      55.000000    84.000000   147.000000     90.000000     8.120000
# max     112.000000   133.000000   231.000000    119.000000    33.460000
#
#             height       weight          bmi  family_diabetes  hypertensive  \
# count  5437.000000  5437.000000  5437.000000      5437.000000   5437.000000
# mean      1.548571    53.626816    22.472301         0.037337      0.109803
# std       0.080955    10.091550     8.778764         0.189603      0.312673
# ...

# %% [markdown]
# # Data Cleaning

# %%
df.isnull()
# Out:
#         age  gender  pulse_rate  systolic_bp  diastolic_bp  glucose  height  \
# 0     False   False       False        False         False    False   False
# 1     False   False       False        False         False    False   False
# 2     False   False       False        False         False    False   False
# 3     False   False       False        False         False    False   False
# 4     False   False       False        False         False    False   False
# ...     ...     ...         ...          ...           ...      ...     ...
# 5432  False   False       False        False         False    False   False
# 5433  False   False       False        False         False    False   False
# 5434  False   False       False        False         False    False   False
# 5435  False   False       False        False         False    False   False
# 5436  False   False       False        False         False    False   False
#
# ...

# %%
df.isnull().sum()
# Out:
# age                       0
# gender                    0
# pulse_rate                0
# systolic_bp               0
# diastolic_bp              0
# glucose                   0
# height                    0
# weight                    0
# bmi                       0
# family_diabetes           0
# hypertensive              0
# family_hypertension       0
# cardiovascular_disease    0
# stroke                    0
# diabetic                  0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [age, gender, pulse_rate, systolic_bp, diastolic_bp, glucose, height, weight, bmi, family_diabetes, hypertensive, family_hypertension, cardiovascular_disease, stroke, diabetic]
# Index: []

# %% [markdown]
# ## Outliers

# %%
sns.boxplot(x=df['age'])
# Out:
# <Axes: xlabel='age'>

# %%
Q1 = df['age'].quantile(0.25)
Q3 = df['age'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)

# Filter the outlier values in the 'age' column
outliers = df[(df['age'] < lower_bound) | (df['age'] > upper_bound)]

# Display the outlier values
outliers
# Out:
#       age  gender  pulse_rate  systolic_bp  diastolic_bp  glucose  height  \
# 360    90  Female          60          222           111     7.58    1.60
# 404    90    Male          68          180            76     8.44    1.65
# 487    97    Male         121          143            88     8.68    1.55
# 633    94  Female          81          187            86     5.12    1.32
# 713   105    Male          78          160            85     9.77    1.63
# 768    90    Male          63          132            59     7.77    1.52
# 887    90    Male          93          179            95     6.40    1.47
# 1250   95    Male          71          148            75     7.20    1.60
# 1769  105  Female          90          153            77     8.64    1.47
# 1862   93    Male          79          110            67     8.32    1.65
# 2404   90    Male          62          161            71     7.59    1.52
# 2682  100  Female          73          162            78     8.08    1.47
# ...

# %%
# Filter the non-outlier values in the 'age' column
non_outliers = df[(df['age'] >= lower_bound) & (df['age'] <= upper_bound)]

# Display the non-outlier values
non_outliers
# Out:
#       age  gender  pulse_rate  systolic_bp  diastolic_bp  glucose  height  \
# 0      42  Female          66          110            73     5.88    1.65
# 1      35  Female          60          125            68     5.71    1.47
# 2      62  Female          57          127            74     6.85    1.52
# 3      73    Male          55          193           112     6.28    1.63
# 4      68  Female          71          150            81     5.71    1.42
# ...   ...     ...         ...          ...           ...      ...     ...
# 5432   74    Male          83          164            89     6.47    1.60
# 5433   75    Male          67          141           104     8.31    1.65
# 5434   40  Female          67          134           114     7.61    1.50
# 5435   36  Female          62          139            80     4.90    1.52
# 5436   26  Female          80          134            93     5.15    1.47
#
#       weight    bmi  family_diabetes  hypertensive  family_hypertension  \
# ...

# %%
non_outliers.shape
# Out:
# (5414, 15)

# %%
df = non_outliers
sns.boxplot(x=df['age'])
# Out:
# <Axes: xlabel='age'>

# %% [markdown]
# ## Categorical Data Handling

# %%
df['diabetic'].value_counts()
# Out:
# diabetic
# No     5070
# Yes     344
# Name: count, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# gender
# Female    3849
# Male      1565
# Name: count, dtype: int64

# %%
df['diabetic'].value_counts().plot(kind = 'bar', color = ['blue', 'red']) 
plt.title('Diabetic Distribution')
plt.xlabel('Diabetic')
plt.ylabel('Count')
plt.show()

# %%
df['diabetic'].value_counts().plot(kind = 'pie', color = ['blue', 'orange']) 
plt.title('Diabetic Distribution')
plt.show()

# %%
df['gender'].value_counts().plot(kind = 'bar', color = ['blue', 'orange']) 
plt.title('gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
df['gender'].value_counts().plot(kind = 'pie', color = ['blue', 'orange']) 
plt.title('gender Distribution')
plt.show()

# %%
# Plot histograms for numerical columns
diabetes.hist(bins=30, figsize=(15, 10))
plt.tight_layout()
plt.show()

# %% [markdown]
# # Catagorical Label Encoding

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5414 entries, 0 to 5436
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     5414 non-null   int64
#  1   gender                  5414 non-null   category
#  2   pulse_rate              5414 non-null   int64
#  3   systolic_bp             5414 non-null   int64
#  4   diastolic_bp            5414 non-null   int64
#  5   glucose                 5414 non-null   float64
#  6   height                  5414 non-null   float64
#  7   weight                  5414 non-null   float64
#  8   bmi                     5414 non-null   float64
#  9   family_diabetes         5414 non-null   int64
#  10  hypertensive            5414 non-null   int64
#  11  family_hypertension     5414 non-null   int64
#  12  cardiovascular_disease  5414 non-null   int64
#  13  stroke                  5414 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df.loc[:, 'gender'] = le.fit_transform(df['gender'])
df.loc[:, 'diabetic'] = le.fit_transform(df['diabetic'])

# %%
df.head()
# Out:
#    age  gender  pulse_rate  systolic_bp  diastolic_bp  glucose  height  \
# 0   42       0          66          110            73     5.88    1.65
# 1   35       0          60          125            68     5.71    1.47
# 2   62       0          57          127            74     6.85    1.52
# 3   73       1          55          193           112     6.28    1.63
# 4   68       0          71          150            81     5.71    1.42
#
#    weight    bmi  family_diabetes  hypertensive  family_hypertension  \
# 0    70.2  25.75                0             0                    0
# 1    42.5  19.58                0             0                    0
# 2    47.0  20.24                0             0                    0
# 3    57.4  21.72                0             0                    0
# 4    36.0  17.79                0             0                    0
#
#    cardiovascular_disease  stroke  diabetic
# 0                       0       0         0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5414 entries, 0 to 5436
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     5414 non-null   int64
#  1   gender                  5414 non-null   int64
#  2   pulse_rate              5414 non-null   int64
#  3   systolic_bp             5414 non-null   int64
#  4   diastolic_bp            5414 non-null   int64
#  5   glucose                 5414 non-null   float64
#  6   height                  5414 non-null   float64
#  7   weight                  5414 non-null   float64
#  8   bmi                     5414 non-null   float64
#  9   family_diabetes         5414 non-null   int64
#  10  hypertensive            5414 non-null   int64
#  11  family_hypertension     5414 non-null   int64
#  12  cardiovascular_disease  5414 non-null   int64
#  13  stroke                  5414 non-null   int64
# ...

# %% [markdown]
# # Feature Engineering

# %%
correlations = df.corr(method = 'pearson')
correlations['diabetic'].sort_values(ascending = False)
# Out:
# diabetic                  1.000000
# hypertensive              0.354770
# glucose                   0.305682
# systolic_bp               0.156768
# diastolic_bp              0.156696
# weight                    0.107889
# cardiovascular_disease    0.095387
# age                       0.093911
# pulse_rate                0.046476
# bmi                       0.042332
# stroke                    0.034065
# height                    0.033424
# gender                    0.027663
# family_hypertension      -0.018073
# family_diabetes          -0.023510
# Name: diabetic, dtype: float64

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(correlations, annot=True, cmap="coolwarm",linewidths=0.5)
plt.title("Correlation Matrix")
plt.show()

# %%
new_correlations = df[['diabetic', 'hypertensive', 'glucose', 'systolic_bp', 'diastolic_bp']].corr()
plt.figure(figsize=(6, 5))
sns.heatmap(new_correlations, annot=True, cmap="crest", linewidths=0.5)
plt.title("Correlation Matrix")
plt.show()

# %%
new_correlations = df[['diabetic', 'hypertensive', 'glucose', 'systolic_bp', 'diastolic_bp']].corr()
plt.figure(figsize=(6, 5))
sns.heatmap(new_correlations, annot=True, cmap="seismic", linewidths=0.5)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# # Seperating Features & Labels

# %%
from sklearn.utils import shuffle
df = shuffle(df)
df
# Out:
#       age  gender  pulse_rate  systolic_bp  diastolic_bp  glucose  height  \
# 4164   45       0          61          172           118     6.94    1.55
# 2962   32       1          72          129            82     6.20    1.68
# 3140   67       1          79          161            81    17.52    1.60
# 2508   32       0          65          113            71    10.13    1.55
# 584    65       1          52          164            78     4.74    1.68
# ...   ...     ...         ...          ...           ...      ...     ...
# 721    40       1          92          111            65     7.49    1.65
# 4484   32       1          75          127            72     6.82    1.63
# 5298   65       1          61          170            86     5.78    1.60
# 4649   65       1          56          192           116     5.52    1.68
# 4871   40       1          81          130            86    12.04    1.65
#
#       weight    bmi  family_diabetes  hypertensive  family_hypertension  \
# ...

# %%
df = df.reset_index()
df
# Out:
#       level_0  index  age  gender  pulse_rate  systolic_bp  diastolic_bp  \
# 0           0   4164   45       0          61          172           118
# 1           1   2962   32       1          72          129            82
# 2           2   3140   67       1          79          161            81
# 3           3   2508   32       0          65          113            71
# 4           4    584   65       1          52          164            78
# ...       ...    ...  ...     ...         ...          ...           ...
# 5409     5409    721   40       1          92          111            65
# 5410     5410   4484   32       1          75          127            72
# 5411     5411   5298   65       1          61          170            86
# 5412     5412   4649   65       1          56          192           116
# 5413     5413   4871   40       1          81          130            86
#
#       glucose  height  weight    bmi  family_diabetes  hypertensive  \
# ...

# %%
x = df.drop('diabetic', axis=1)
y = df['diabetic']

# %%
x.head()
# Out:
#    level_0  index  age  gender  pulse_rate  systolic_bp  diastolic_bp  \
# 0        0   4164   45       0          61          172           118
# 1        1   2962   32       1          72          129            82
# 2        2   3140   67       1          79          161            81
# 3        3   2508   32       0          65          113            71
# 4        4    584   65       1          52          164            78
#
#    glucose  height  weight    bmi  family_diabetes  hypertensive  \
# 0     6.94    1.55    62.4  25.99                0             0
# 1     6.20    1.68    58.1  20.67                1             0
# 2    17.52    1.60    50.8  19.84                0             0
# 3    10.13    1.55    41.0  17.08                0             0
# 4     4.74    1.68    61.3  21.81                0             1
#
#    family_hypertension  cardiovascular_disease  stroke
# 0                    0                       0       0
# ...

# %%
x.columns
# Out:
# Index(['level_0', 'index', 'age', 'gender', 'pulse_rate', 'systolic_bp',
#        'diastolic_bp', 'glucose', 'height', 'weight', 'bmi', 'family_diabetes',
#        'hypertensive', 'family_hypertension', 'cardiovascular_disease',
#        'stroke'],
#       dtype='object')

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 5409    0
# 5410    0
# 5411    0
# 5412    0
# 5413    0
# Name: diabetic, Length: 5414, dtype: int64

# %% [markdown]
# ## Data Scaling

# %%
plt.hist(x)
plt.show()

# %% [markdown]
# ## Standard Scalar Transform

# %%
from sklearn.preprocessing import StandardScaler

std_scaler = StandardScaler()  
std_scaled_x = std_scaler.fit_transform(x)  

std_scaled_x
# Out:
# array([[-1.73173092,  0.92084546, -0.02310681, ..., -0.20335709,
#         -0.10586111, -0.0608919 ],
#        [-1.73109107,  0.1549053 , -0.9534863 , ...,  4.91745822,
#         -0.10586111, -0.0608919 ],
#        [-1.73045123,  0.26833072,  1.55138157, ..., -0.20335709,
#         -0.10586111, -0.0608919 ],
#        ...,
#        [ 1.73045123,  1.64345455,  1.40824626, ..., -0.20335709,
#         -0.10586111, -0.0608919 ],
#        [ 1.73109107,  1.22989785,  1.40824626, ..., -0.20335709,
#         -0.10586111, -0.0608919 ],
#        [ 1.73173092,  1.37136101, -0.38094508, ..., -0.20335709,
#         -0.10586111, -0.0608919 ]], shape=(5414, 16))

# %%
plt.hist(std_scaled_x)
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

m_scaler = MinMaxScaler()  # Corrected the typo here
m_scaled_x = m_scaler.fit_transform(x)  # Assuming 'x' is your input data

m_scaled_x
# Out:
# array([[0.00000000e+00, 7.66004415e-01, 4.80519481e-01, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.84740440e-04, 5.44885946e-01, 3.11688312e-01, ...,
#         1.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [3.69480879e-04, 5.77630611e-01, 7.66233766e-01, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [9.99630519e-01, 9.74613687e-01, 7.40259740e-01, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [9.99815260e-01, 8.55224430e-01, 7.40259740e-01, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.00000000e+00, 8.96063282e-01, 4.15584416e-01, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00]], shape=(5414, 16))

# %%
plt.hist(m_scaled_x)
plt.show()

# %% [markdown]
# # Train-test Split

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2)

print("train data size", len(y_train))
print("test data size", len(y_test))
# Out:
# train data size 4331
# test data size 1083

# %%
print("train data size", len(x_train))
print("test data size", len(x_test))
# Out:
# train data size 4331
# test data size 1083
