# %% [markdown]
# # Data Structure

# %%
import pandas as pd

# %%
csv_path = "/Users/saifmohammed/Desktop/CSE299/ML/Test/Copy Dataset/Diabetes_Final_Data_V2.csv"
diabetes = pd.read_csv(csv_path)
diabetes
# Out:
#       age  gender  pulse_rate  systolic_bp  diastolic_bp  glucose  height  \
# 0      42  Female          66          110            73     5.88    1.65
# 1      35  Female          60          125            68     5.71    1.47
# 2      62  Female          57          127            74     6.85    1.52
# 3      73    Male          55          193           112     6.28    1.63
# 4      68  Female          71          150            81     5.71    1.42
# ...   ...     ...         ...          ...           ...      ...     ...
# 5432   74    Male          83          164            89     6.47    1.60
# 5433   75    Male          67          141           104     8.31    1.65
# 5434   40  Female          67          134           114     7.61    1.50
# 5435   36  Female          62          139            80     4.90    1.52
# 5436   26  Female          80          134            93     5.15    1.47
#
#       weight    bmi  family_diabetes  hypertensive  family_hypertension  \
# ...

# %%
diabetes.head()
# Out:
#    age  gender  pulse_rate  systolic_bp  diastolic_bp  glucose  height  \
# 0   42  Female          66          110            73     5.88    1.65
# 1   35  Female          60          125            68     5.71    1.47
# 2   62  Female          57          127            74     6.85    1.52
# 3   73    Male          55          193           112     6.28    1.63
# 4   68  Female          71          150            81     5.71    1.42
#
#    weight    bmi  family_diabetes  hypertensive  family_hypertension  \
# 0    70.2  25.75                0             0                    0
# 1    42.5  19.58                0             0                    0
# 2    47.0  20.24                0             0                    0
# 3    57.4  21.72                0             0                    0
# 4    36.0  17.79                0             0                    0
#
#    cardiovascular_disease  stroke diabetic
# 0                       0       0       No
# ...

# %%
diabetes.columns
# Out:
# Index(['age', 'gender', 'pulse_rate', 'systolic_bp', 'diastolic_bp', 'glucose',
#        'height', 'weight', 'bmi', 'family_diabetes', 'hypertensive',
#        'family_hypertension', 'cardiovascular_disease', 'stroke', 'diabetic'],
#       dtype='object')

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5437 entries, 0 to 5436
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     5437 non-null   int64
#  1   gender                  5437 non-null   object
#  2   pulse_rate              5437 non-null   int64
#  3   systolic_bp             5437 non-null   int64
#  4   diastolic_bp            5437 non-null   int64
#  5   glucose                 5437 non-null   float64
#  6   height                  5437 non-null   float64
#  7   weight                  5437 non-null   float64
#  8   bmi                     5437 non-null   float64
#  9   family_diabetes         5437 non-null   int64
#  10  hypertensive            5437 non-null   int64
#  11  family_hypertension     5437 non-null   int64
#  12  cardiovascular_disease  5437 non-null   int64
#  13  stroke                  5437 non-null   int64
# ...

# %%
diabetes.describe()
# Out:
#                age   pulse_rate  systolic_bp  diastolic_bp      glucose  \
# count  5437.000000  5437.000000  5437.000000   5437.000000  5437.000000
# mean     45.533750    76.768990   133.859849     82.064742     7.540682
# std      14.321155    12.290076    22.293015     12.489593     2.923080
# min       8.000000     5.000000    62.000000     45.000000     0.000000
# 25%      35.000000    69.000000   119.000000     73.000000     6.000000
# 50%      45.000000    76.000000   130.000000     81.000000     6.920000
# 75%      55.000000    84.000000   147.000000     90.000000     8.120000
# max     112.000000   133.000000   231.000000    119.000000    33.460000
#
#             height       weight          bmi  family_diabetes  hypertensive  \
# count  5437.000000  5437.000000  5437.000000      5437.000000   5437.000000
# mean      1.548571    53.626816    22.472301         0.037337      0.109803
# std       0.080955    10.091550     8.778764         0.189603      0.312673
# ...

# %%
import matplotlib.pyplot as plt

# %%
diabetes.hist(bins=50, figsize=(20, 15))
plt.show()

# %% [markdown]
# # Test Set

# %%
import numpy as np

# %%
def split_train_test(data, test_ratio):
    shuffled_indices = np.random.permutation(len(data))
    test_set_size = int(len(data) * test_ratio)
    test_indices = shuffled_indices[:test_set_size]
    train_indices = shuffled_indices[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]

# %%
train_set, test_set = split_train_test(diabetes, 0.2)

# %%
len(train_set)
# Out:
# 4350

# %%
len(test_set)
# Out:
# 1087

# %%
from zlib import crc32

# %%
def test_set_check(identifier, test_ratio):
    return crc32(np.int64(identifier)) & 0xffffffff < test_ratio * 2**32

# %%
def split_train_test_by_id(data, test_ratio, id_column):
    ids = data[id_column]
    in_test_set = ids.apply(lambda id_: test_set_check(id_, test_ratio))
    return data.loc[~in_test_set], data.loc[in_test_set]

# %%
diabetes_with_id = diabetes.reset_index() # adds an `index` column
train_set, test_set = split_train_test_by_id(diabetes_with_id, 0.2, "index")

# %%
diabetes_with_id["id"] = diabetes["systolic_bp"] * 1000 + diabetes["diastolic_bp"]
train_set, test_set = split_train_test_by_id(diabetes_with_id, 0.2, "id")

# %%
from sklearn.model_selection import train_test_split

# %%
train_set, test_set = train_test_split(diabetes, test_size=0.2, random_state=42)

# %%
print(diabetes["glucose"].value_counts())
# Out:
# glucose
# 6.00     120
# 5.00     103
# 7.00      73
# 8.00      67
# 9.00      50
#         ...
# 8.79       1
# 12.07      1
# 11.03      1
# 21.04      1
# 1.62       1
# Name: count, Length: 941, dtype: int64

# %%
diabetes["glucose_cat"] = pd.cut(diabetes["glucose"],
                                 bins=[0, 100, 150, 200, np.inf],
                                 labels=["low", "medium", "high", "very high"])

# %%
diabetes = diabetes[diabetes["glucose"].map(diabetes["glucose"].value_counts()) > 1]

# %%
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index, test_index in split.split(diabetes, diabetes["glucose_cat"]):
    strat_train_set = diabetes.loc[train_index]
    strat_test_set = diabetes.loc[test_index]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 3
#       1 split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
#       2 for train_index, test_index in split.split(diabetes, diabetes["glucose_cat"]):
# ----> 3     strat_train_set = diabetes.loc[train_index]
#       4     strat_test_set = diabetes.loc[test_index]
#
# File ~/Desktop/CSE299/ML/my_env/lib/python3.12/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/Desktop/CSE299/ML/my_env/lib/python3.12/site-packages/pandas/core/indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
# ...

# %%
diabetes.plot(kind="scatter", x="systolic_bp", y="diastolic_bp")
# Out:
# <Axes: xlabel='systolic_bp', ylabel='diastolic_bp'>

# %%
diabetes.plot(kind="scatter", x="systolic_bp", y="diastolic_bp", alpha=0.1)
# Out:
# <Axes: xlabel='systolic_bp', ylabel='diastolic_bp'>

# %%
diabetes.plot(
    kind="scatter",
    x="systolic_bp",
    y="diastolic_bp",
    alpha=0.4,
    s=diabetes["age"],  # Bubble size
    label="age",
    figsize=(10, 7),
    c="bp",  # Color
    cmap=plt.get_cmap("jet"),  # Colormap
    colorbar=True,
)
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Desktop/CSE299/ML/my_env/lib/python3.12/site-packages/matplotlib/axes/_axes.py:4725, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4724 try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4725     colors = mcolors.to_rgba_array(c)
#    4726 except (TypeError, ValueError) as err:
#
# File ~/Desktop/CSE299/ML/my_env/lib/python3.12/site-packages/matplotlib/colors.py:498, in to_rgba_array(c, alpha)
#     497 if isinstance(c, str):
# --> 498     raise ValueError(f"{c!r} is not a valid color value.")
#     500 if len(c) == 0:
#
# ValueError: 'bp' is not a valid color value.
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 diabetes.plot(
# ...
