# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Load & Inspect Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
csv_path = "/Users/saifmohammed/Desktop/CSE299/ML/Test/Copy Dataset/Diabetes_Final_Data_V2.csv"
diabetes = pd.read_csv(csv_path)
diabetes
# Out:
#       age  gender  pulse_rate  systolic_bp  diastolic_bp  glucose  height  \
# 0      42  Female          66          110            73     5.88    1.65
# 1      35  Female          60          125            68     5.71    1.47
# 2      62  Female          57          127            74     6.85    1.52
# 3      73    Male          55          193           112     6.28    1.63
# 4      68  Female          71          150            81     5.71    1.42
# ...   ...     ...         ...          ...           ...      ...     ...
# 5432   74    Male          83          164            89     6.47    1.60
# 5433   75    Male          67          141           104     8.31    1.65
# 5434   40  Female          67          134           114     7.61    1.50
# 5435   36  Female          62          139            80     4.90    1.52
# 5436   26  Female          80          134            93     5.15    1.47
#
#       weight    bmi  family_diabetes  hypertensive  family_hypertension  \
# 0       70.2  25.75                0             0                    0
# 1       42.5  19.58                0             0                    0
# 2       47.0  20.24                0             0                    0
# 3       57.4  21.72                0             0                    0
# 4       36.0  17.79                0             0                    0
# ...      ...    ...              ...           ...                  ...
# 5432    64.0  24.99                0             1                    0
# 5433    62.0  22.75                0             0                    0
# 5434    69.0  30.72                0             1                    0
# 5435    41.5  17.87                0             0                    0
# 5436    67.1  30.92                0             0                    0
#
#       cardiovascular_disease  stroke diabetic
# 0                          0       0       No
# 1                          0       0       No
# 2                          0       0       No
# 3                          0       0       No
# 4                          0       0       No
# ...                      ...     ...      ...
# 5432                       1       0       No
# 5433                       0       0      Yes
# 5434                       0       1       No
# 5435                       0       0       No
# 5436                       0       0       No
#
# [5437 rows x 15 columns]

# %%
diabetes.head()
# Out:
#    age  gender  pulse_rate  systolic_bp  diastolic_bp  glucose  height  \
# 0   42  Female          66          110            73     5.88    1.65
# 1   35  Female          60          125            68     5.71    1.47
# 2   62  Female          57          127            74     6.85    1.52
# 3   73    Male          55          193           112     6.28    1.63
# 4   68  Female          71          150            81     5.71    1.42
#
#    weight    bmi  family_diabetes  hypertensive  family_hypertension  \
# 0    70.2  25.75                0             0                    0
# 1    42.5  19.58                0             0                    0
# 2    47.0  20.24                0             0                    0
# 3    57.4  21.72                0             0                    0
# 4    36.0  17.79                0             0                    0
#
#    cardiovascular_disease  stroke diabetic
# 0                       0       0       No
# 1                       0       0       No
# 2                       0       0       No
# 3                       0       0       No
# 4                       0       0       No

# %%
diabetes.columns
# Out:
# Index(['age', 'gender', 'pulse_rate', 'systolic_bp', 'diastolic_bp', 'glucose',
#        'height', 'weight', 'bmi', 'family_diabetes', 'hypertensive',
#        'family_hypertension', 'cardiovascular_disease', 'stroke', 'diabetic'],
#       dtype='object')

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5437 entries, 0 to 5436
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     5437 non-null   int64
#  1   gender                  5437 non-null   object
#  2   pulse_rate              5437 non-null   int64
#  3   systolic_bp             5437 non-null   int64
#  4   diastolic_bp            5437 non-null   int64
#  5   glucose                 5437 non-null   float64
#  6   height                  5437 non-null   float64
#  7   weight                  5437 non-null   float64
#  8   bmi                     5437 non-null   float64
#  9   family_diabetes         5437 non-null   int64
#  10  hypertensive            5437 non-null   int64
#  11  family_hypertension     5437 non-null   int64
#  12  cardiovascular_disease  5437 non-null   int64
#  13  stroke                  5437 non-null   int64
#  14  diabetic                5437 non-null   object
# dtypes: float64(4), int64(9), object(2)
# memory usage: 637.3+ KB

# %%
diabetes.describe()
# Out:
#                age   pulse_rate  systolic_bp  diastolic_bp      glucose  \
# count  5437.000000  5437.000000  5437.000000   5437.000000  5437.000000
# mean     45.533750    76.768990   133.859849     82.064742     7.540682
# std      14.321155    12.290076    22.293015     12.489593     2.923080
# min       8.000000     5.000000    62.000000     45.000000     0.000000
# 25%      35.000000    69.000000   119.000000     73.000000     6.000000
# 50%      45.000000    76.000000   130.000000     81.000000     6.920000
# 75%      55.000000    84.000000   147.000000     90.000000     8.120000
# max     112.000000   133.000000   231.000000    119.000000    33.460000
#
#             height       weight          bmi  family_diabetes  hypertensive  \
# count  5437.000000  5437.000000  5437.000000      5437.000000   5437.000000
# mean      1.548571    53.626816    22.472301         0.037337      0.109803
# std       0.080955    10.091550     8.778764         0.189603      0.312673
# min       0.360000     3.000000     1.220000         0.000000      0.000000
# 25%       1.520000    46.700000    19.630000         0.000000      0.000000
# 50%       1.550000    53.000000    21.870000         0.000000      0.000000
# 75%       1.600000    59.900000    24.490000         0.000000      0.000000
# max       1.960000   100.700000   574.130000         1.000000      1.000000
#
#        family_hypertension  cardiovascular_disease       stroke
# count          5437.000000             5437.000000  5437.000000
# mean              0.039544                0.011587     0.003678
# std               0.194903                0.107029     0.060545
# min               0.000000                0.000000     0.000000
# 25%               0.000000                0.000000     0.000000
# 50%               0.000000                0.000000     0.000000
# 75%               0.000000                0.000000     0.000000
# max               1.000000                1.000000     1.000000

# %%
diabetes.nunique()
# Out:
# age                         85
# gender                       2
# pulse_rate                  92
# systolic_bp                136
# diastolic_bp                73
# glucose                    941
# height                      55
# weight                     513
# bmi                       1385
# family_diabetes              2
# hypertensive                 2
# family_hypertension          2
# cardiovascular_disease       2
# stroke                       2
# diabetic                     2
# dtype: int64

# %%
diabetes.isnull().sum()
# Out:
# age                       0
# gender                    0
# pulse_rate                0
# systolic_bp               0
# diastolic_bp              0
# glucose                   0
# height                    0
# weight                    0
# bmi                       0
# family_diabetes           0
# hypertensive              0
# family_hypertension       0
# cardiovascular_disease    0
# stroke                    0
# diabetic                  0
# dtype: int64

# %%
# Calculate gender distribution
gender_distribution = diabetes['gender'].value_counts(normalize=True) * 100
gender_distribution
# Out:
# gender
# Female    70.976642
# Male      29.023358
# Name: proportion, dtype: float64

# %%
# Plot histograms for numerical columns
diabetes.hist(bins=30, figsize=(15, 10))
plt.tight_layout()
plt.show()

# %%
# Plot count of gender
plt.figure(figsize=(6, 4))
sns.countplot(x='gender', data=diabetes)
plt.title("Distribution of Gender")
plt.show()

# Plot count of diabetic
plt.figure(figsize=(6, 4))
sns.countplot(x='diabetic', data=diabetes)
plt.title("Distribution of Diabetic")
plt.show()

# %%
import math

# List of numerical features
numerical_features = [col for col in diabetes.columns if diabetes[col].dtype in ['int64', 'float64']]

# Calculate the number of rows and columns needed
num_features = len(numerical_features)
num_cols = 3  # Number of columns in the subplot grid
num_rows = math.ceil(num_features / num_cols)  # Number of rows needed

# %%
plt.figure(figsize=(15, 5 * num_rows))  # Adjust figure size based on the number of rows

for i, feature in enumerate(numerical_features, 1):
    plt.subplot(num_rows, num_cols, i)  # Use dynamic grid size
    sns.boxplot(x='diabetic', y=feature, data=diabetes)
    plt.title(f"{feature} vs Diabetic")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='gender', hue='diabetic', data=diabetes)
plt.title("Gender vs Diabetic")
plt.show()

# %%
# Encode 'gender' and 'diabetic' columns
diabetes['gender'] = diabetes['gender'].map({'Male': 1, 'Female': 0})
diabetes['diabetic'] = diabetes['diabetic'].map({'Yes': 1, 'No': 0})

# %%
diabetes['bmi_category'] = pd.cut(
    diabetes['bmi'], 
    bins=[0, 18.5, 24.9, 29.9, float('inf')],  # Define BMI bins
    labels=[1, 2, 3, 4],  # Assign numerical labels
    right=True  # Include the right edge of the bin
)

# %%
diabetes['bp_ratio'] = diabetes['systolic_bp'] / diabetes['diastolic_bp']

# %%
# Compute correlation matrix
corr_matrix = diabetes.corr()

# Display the correlation matrix
corr_matrix
# Out:
#                              age    gender  pulse_rate  systolic_bp  \
# age                     1.000000  0.214244   -0.157676     0.366832
# gender                  0.214244  1.000000   -0.179535    -0.000197
# pulse_rate             -0.157676 -0.179535    1.000000    -0.187403
# systolic_bp             0.366832 -0.000197   -0.187403     1.000000
# diastolic_bp            0.117926 -0.029209   -0.028569     0.715792
# glucose                 0.107166 -0.016112    0.132098     0.082810
# height                  0.011743  0.503593   -0.056240    -0.057382
# weight                 -0.157037  0.192634   -0.000517     0.094915
# bmi                    -0.093035 -0.025006    0.003199     0.083038
# family_diabetes        -0.194529  0.070714    0.000307    -0.068571
# hypertensive            0.220543  0.015205   -0.063003     0.357435
# family_hypertension    -0.196845  0.074025    0.005120    -0.066889
# cardiovascular_disease  0.077336  0.040574   -0.030410     0.059045
# stroke                  0.051836  0.041470   -0.034953     0.068529
# diabetic                0.087600  0.026899    0.046014     0.155269
# bmi_category           -0.160293 -0.088142    0.027080     0.110785
# bp_ratio                0.352061  0.038573   -0.222745     0.459781
#
#                         diastolic_bp   glucose    height    weight       bmi  \
# age                         0.117926  0.107166  0.011743 -0.157037 -0.093035
# gender                     -0.029209 -0.016112  0.503593  0.192634 -0.025006
# pulse_rate                 -0.028569  0.132098 -0.056240 -0.000517  0.003199
# systolic_bp                 0.715792  0.082810 -0.057382  0.094915  0.083038
# diastolic_bp                1.000000  0.076703 -0.024585  0.209697  0.117251
# glucose                     0.076703  1.000000 -0.004233  0.041454  0.011774
# height                     -0.024585 -0.004233  1.000000  0.341015 -0.299654
# weight                      0.209697  0.041454  0.341015  1.000000  0.416416
# bmi                         0.117251  0.011774 -0.299654  0.416416  1.000000
# family_diabetes            -0.020053 -0.011949  0.040630  0.083265  0.026653
# hypertensive                0.283504  0.111221  0.005764  0.099530  0.050887
# family_hypertension        -0.016015 -0.021145  0.035528  0.083290  0.028002
# cardiovascular_disease      0.044027  0.036213 -0.000424  0.035479  0.016494
# stroke                      0.062207  0.004196  0.015335  0.025762  0.007474
# diabetic                    0.156728  0.305426  0.033334  0.108157  0.042708
# bmi_category                0.211692  0.046392 -0.165758  0.771868  0.462432
# bp_ratio                   -0.279000  0.022936 -0.046856 -0.129853 -0.034306
#
#                         family_diabetes  hypertensive  family_hypertension  \
# age                           -0.194529      0.220543            -0.196845
# gender                         0.070714      0.015205             0.074025
# pulse_rate                     0.000307     -0.063003             0.005120
# systolic_bp                   -0.068571      0.357435            -0.066889
# diastolic_bp                  -0.020053      0.283504            -0.016015
# glucose                       -0.011949      0.111221            -0.021145
# height                         0.040630      0.005764             0.035528
# weight                         0.083265      0.099530             0.083290
# bmi                            0.026653      0.050887             0.028002
# family_diabetes                1.000000     -0.044342             0.965600
# hypertensive                  -0.044342      1.000000            -0.038058
# family_hypertension            0.965600     -0.038058             1.000000
# cardiovascular_disease        -0.012258      0.154371            -0.004332
# stroke                         0.004059      0.114705             0.003260
# diabetic                      -0.023288      0.353356            -0.017845
# bmi_category                   0.063848      0.096526             0.065600
# bp_ratio                      -0.066501      0.128303            -0.068735
#
#                         cardiovascular_disease    stroke  diabetic  \
# age                                   0.077336  0.051836  0.087600
# gender                                0.040574  0.041470  0.026899
# pulse_rate                           -0.030410 -0.034953  0.046014
# systolic_bp                           0.059045  0.068529  0.155269
# diastolic_bp                          0.044027  0.062207  0.156728
# glucose                               0.036213  0.004196  0.305426
# height                               -0.000424  0.015335  0.033334
# weight                                0.035479  0.025762  0.108157
# bmi                                   0.016494  0.007474  0.042708
# family_diabetes                      -0.012258  0.004059 -0.023288
# hypertensive                          0.154371  0.114705  0.353356
# family_hypertension                  -0.004332  0.003260 -0.017845
# cardiovascular_disease                1.000000  0.050198  0.091872
# stroke                                0.050198  1.000000  0.034127
# diabetic                              0.091872  0.034127  1.000000
# bmi_category                          0.047911  0.020143  0.089998
# bp_ratio                              0.022914  0.012139  0.016942
#
#                         bmi_category  bp_ratio
# age                        -0.160293  0.352061
# gender                     -0.088142  0.038573
# pulse_rate                  0.027080 -0.222745
# systolic_bp                 0.110785  0.459781
# diastolic_bp                0.211692 -0.279000
# glucose                     0.046392  0.022936
# height                     -0.165758 -0.046856
# weight                      0.771868 -0.129853
# bmi                         0.462432 -0.034306
# family_diabetes             0.063848 -0.066501
# hypertensive                0.096526  0.128303
# family_hypertension         0.065600 -0.068735
# cardiovascular_disease      0.047911  0.022914
# stroke                      0.020143  0.012139
# diabetic                    0.089998  0.016942
# bmi_category                1.000000 -0.109828
# bp_ratio                   -0.109828  1.000000

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix")
plt.show()
